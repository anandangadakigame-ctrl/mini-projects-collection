# %%
pip install opendatasets

# %%
import opendatasets as od
od.download('https://www.kaggle.com/datasets/ankushpanday2/indian-kids-screentime-2025')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: anandangadakianan
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/ankushpanday2/indian-kids-screentime-2025
# ...
# 100%|██████████| 68.4k/68.4k [00:00<00:00, 97.7MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('indian-kids-screentime-2025/Indian_Kids_Screen_Time.csv')
data.head()
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# ...

# %%
import os
print(os.listdir('indian-kids-screentime-2025'))
# Out:
# ['Indian_Kids_Screen_Time.csv']

# %%
ceditdata=data.copy()
ceditdata.head()
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# ...

# %%
ceditdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB

# %%
for features in ceditdata.columns:
    print(features,ceditdata[features].unique())
# Out:
# Age [14 11 18 15 12 17 10 13  9  8 16]
# Gender ['Male' 'Female']
# Avg_Daily_Screen_Time_hr [3.990e+00 4.610e+00 3.730e+00 1.210e+00 5.890e+00 4.880e+00 2.970e+00
#  2.740e+00 3.240e+00 3.530e+00 4.940e+00 4.590e+00 6.080e+00 6.150e+00
#  3.690e+00 7.100e+00 6.980e+00 3.820e+00 0.000e+00 3.850e+00 4.050e+00
#  1.630e+00 6.780e+00 3.190e+00 4.960e+00 1.850e+00 4.220e+00 3.100e-01
#  5.130e+00 4.450e+00 3.020e+00 2.160e+00 4.280e+00 5.340e+00 3.500e+00
#  1.168e+01 4.630e+00 4.210e+00 4.560e+00 3.510e+00 4.690e+00 7.610e+00
#  2.750e+00 6.740e+00 2.340e+00 2.850e+00 4.290e+00 6.030e+00 1.060e+00
#  2.830e+00 3.920e+00 4.550e+00 6.860e+00 3.470e+00 4.310e+00 2.300e+00
#  4.500e+00 2.650e+00 3.870e+00 5.670e+00 3.800e+00 9.000e-01 3.300e+00
#  5.120e+00 5.820e+00 4.270e+00 5.790e+00 2.690e+00 3.640e+00 4.230e+00
#  5.720e+00 3.410e+00 2.900e+00 7.540e+00 4.340e+00 5.430e+00 4.780e+00
#  1.670e+00 5.910e+00 6.300e+00 3.390e+00 3.570e+00 1.360e+00 6.400e+00
# ...

# %%
print(ceditdata.isnull().sum())
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64

# %%
ceditdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Educational_to_Recreational_Ratio  9712 non-null   float64
#  5   Health_Impacts                     6494 non-null   object
#  6   Urban_or_Rural                     9712 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 531.3+ KB

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("Shape of x_train:", x_train.shape)
print("Shape of x_test:", x_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of x_train: (7769, 7)
# Shape of x_test: (1943, 7)
# Shape of y_train: (7769,)
# Shape of y_test: (1943,)

# %%
x_train = pd.get_dummies(x_train, columns=['Gender', 'Primary_Device', 'Health_Impacts', 'Urban_or_Rural'], dummy_na=False)
x_test = pd.get_dummies(x_test, columns=['Gender', 'Primary_Device', 'Health_Impacts', 'Urban_or_Rural'], dummy_na=False)

display(x_train.head())
display(x_test.head())
# Out:
#       Age  Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio  \
# 6889   10                      1.58                               0.46
# 3469   16                      3.87                               0.30
# 3533   16                      3.44                               0.30
# 5786   13                      4.78                               0.41
# 7550   11                      5.60                               0.46
#
#       Gender_Female  Gender_Male  Primary_Device_Laptop  \
# 6889          False         True                  False
# 3469           True        False                   True
# 3533          False         True                  False
# 5786          False         True                  False
# 7550          False         True                  False
#
#       Primary_Device_Smartphone  Primary_Device_TV  Primary_Device_Tablet  \
# 6889                       True              False                  False
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

print("Shape of x_train:", x_train.shape)
print("Shape of x_test:", x_test.shape)
# Out:
# Shape of x_train: (7769, 26)
# Shape of x_test: (1943, 26)

# %%
from sklearn.tree import DecisionTreeClassifier

dTree = DecisionTreeClassifier(criterion='gini',random_state=1)
dTree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
print(dTree.score(x_train, y_train))
print(dTree.score(x_test, y_test))
# Out:
# 1.0
# 1.0

# %%
train_char_label =['no','yes']
cedit_Tree_File = open('cedit_Tree.dot','w')
from sklearn import tree
# Get the column names from the one-hot encoded DataFrame before scaling
feature_names = pd.get_dummies(x, columns=['Gender', 'Primary_Device', 'Health_Impacts', 'Urban_or_Rural'], dummy_na=False).columns
tree.export_graphviz(dTree,out_file=cedit_Tree_File,feature_names=feature_names,class_names=train_char_label,filled=True,rounded=True)
cedit_Tree_File.close()

# %%
from IPython.display import Image
retCode = !dot -Tpng cedit_Tree.dot -o cedit_Tree.png
if retCode:
    print("system command returning error: "+"\n".join(retCode))
else:
   display(Image(filename='cedit_Tree.png'))
